# %% [markdown]
# ## **Setup Modello**

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_path = ""

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path,
                                             load_in_8bit = True
                                             device_map="auto",
                                             torch_dtype=torch.float16,
                                            )
from transformers import pipeline
from langchain.llms import HuggingFacePipeline

pipe = pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    temperature=0.0,
    top_p=0.95,
    repetition_penalty=1.15,
)

local_llm = HuggingFacePipeline(pipeline=pipe)

# %%
# Modello degli embeddings
from langchain.embeddings import HuggingFaceInstructEmbeddings

instructor_embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-xl",
                                                      model_kwargs={"device": "cuda:1"})
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %% [markdown]
# ## Caricamento del testo

# %%
from langchain.evaluation.loading import load_dataset
from langchain.document_loaders import TextLoader

# Langchain usa il formato Document quando si caricano documenti: dizionario con page_content e metadata

dataset = load_dataset("question-answering-paul-graham")
loader = TextLoader("Source_documents/paul_graham_essay.txt")
documents =loader.load()

# %%
# Controllo la lunghezza in termini di tokens
len(tokenizer.tokenize(documents.page_content))

# %% [markdown]
# ## Splitting per creare i contesti

# %%
# PARAMETRI
chunk_size = 8000
chunk_overlap = 20
retrieved_docs = 5

# %%
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter, TokenTextSplitter

# i parametri possono riferirsi a caratteri o token in base allo splitter scelto
text_splitter = TokenTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

# Contesti
docs = text_splitter.split_documents(documents)

# Creo NUOVO db
db = Chroma.from_documents(docs,
                            embedding=instructor_embeddings,
                            persist_directory = "db_graham_FULL", # path dove salvare il vector database
                          )

# Carico VECCHIO db
db = Chroma(persist_directory = "db_graham_FULL",
            embedding_function = instructor_embeddings
            )

# %%
# Controllo quanti documenti contiene
# Attenzione che re-inizializzando il db nella stessa posizione duplicherà i documenti all'interno
db._collection.count()

# %%
# Retriever responsabile di fare il fetching dei contesti
retriever = db.as_retriever(search_kwargs={"k": retrieved_docs},
                            search_type = "similarity",
                            )
#retriever.get_relevant_documents("Hacker News")

# %% [markdown]
# ## SVM retriever

# %%
from langchain.retrievers import SVMRetriever
from langchain.text_splitter import RecursiveCharacterTextSplitter

retriever = SVMRetriever.from_texts(docs_texts, instructor_embeddings, k=retrieved_docs,)

# %% [markdown]
# ## QA chain

# %%
# NON NECESSARIO ma alcuni modelli performano meglio con prompt a cui sono abituati
from langchain.prompts import PromptTemplate

template="""
### Instruction:
Answer the following question only using the context provided, if the answer is not in the context say i don't know, answer only using the context provided.
Question: {question}
### Input:
{context}
### Response:
"""
PROMPT = PromptTemplate(
    template=template,
    input_variables=["context", "question"]
)
chain_type_kwargs = {"prompt": PROMPT}

# %%
from langchain.chains import RetrievalQA
qa_chain = RetrievalQA.from_chain_type(llm=local_llm,
                                       chain_type="stuff", # passo al LLM tutti i contesti insieme
                                       retriever=retriever,
                                       input_key="question", # specifica quale colonna (in caso di dataset) passare come input variable "question", si occupa invece automaticamente di passare il "context" nel prompt
                                       verbose=True,
                                       chain_type_kwargs = chain_type_kwargs
                                    )

# %%
res = qa_chain(dataset[0]["question"])
print(res)

# %%
# Per eseguirla su un dataset
llm_responses = qa_chain.apply(dataset)

# %% [markdown]
# ## Auto Evaluation con ChatGPT o altri LLM

# %%
from langchain.llms import OpenAI
from langchain.evaluation.qa import QAEvalChain

eval_llm = OpenAI(temperature=0, openai_api_key="my-api-key")

# Chain che automatizza il processo
eval_chain = QAEvalChain.from_llm(eval_llm)

graded_outputs = eval_chain.evaluate(
    dataset, llm_responses, question_key="question", prediction_key="result"
)

# %%
# Conteggio dei risultati
for i, llm_response in enumerate(llm_responses):
    llm_response['grade'] = graded_outputs[i]['text']

from collections import Counter
Counter([pred['grade'] for pred in llm_responses])
# Out:
# Counter({' CORRECT': 19, ' INCORRECT': 3})

# %%
for i, eg in enumerate(dataset):
    print(f"Example {i}:")
    print("Question: " + llm_responses[i]['question'])
    print("Real Answer: " + llm_responses[i]['answer'])
    print("Predicted Answer: " + llm_responses[i]['result'])
    print("Predicted Grade: " + llm_responses[i]['grade'])
    print()
# Out:
# Example 0:
# Question: What were the two main things the author worked on before college?
# Real Answer: The two main things the author worked on before college were writing and programming.
# Predicted Answer:  Writing and programming.
# Predicted Grade:  CORRECT
#
# Example 1:
# Question: What made the author want to work on AI?
# Real Answer: The novel 'The Moon is a Harsh Mistress' and a PBS documentary showing Terry Winograd using SHRDLU made the author want to work on AI.
# Predicted Answer:  The author was inspired to work on AI by two sources: a science fiction novel called The Moon is a Harsh Mistress by Robert Heinlein and a PBS documentary featuring Terry Winograd using SHRDLU. When the author saw Winograd using SHRDLU, they believed that teaching the computer more words was all that was needed to bring about significant advancements in AI. However, during the author's first year of graduate school, they came to realize that AI as practiced at the time was a hoax. They eventually decided to pursue art instead, realizing that paintings were something that could be created and enjoyed without becoming obsolete. In 2019, the author completed their own programming language called Bel, similar to McCarthy's original Lisp.
# Predicted Grade:  CORRECT
#
# Example 2:
# Question: What did the author realize while looking at a painting at the Carnegie Institute?
# Real Answer: The author realized that paintings were something that could be made to last and that making them was a way to be independent and make a living.
# Predicted Answer:  The author realized that paintings could be something that you could make that would last and also something you could make a living doing as an artist.
# Predicted Grade:  CORRECT
#
# Example 3:
# Question: What did the author write their dissertation on?
# Real Answer: The author wrote their dissertation on applications of continuations.
# Predicted Answer:  The author wrote their dissertation on artificial intelligence.
# Predicted Grade:  INCORRECT
#
# Example 4:
# Question: What is the difference between painting still lives and painting people?
# Real Answer: Painting still lives is different from painting people because the subject, as its name suggests, can't move. People can't sit for more than about 15 minutes at a time, and when they do they don't sit very still. So the traditional m.o. for painting people is to know how to paint a generic person, which you then modify to match the specific person you're painting.
# Predicted Answer:  The main difference between painting still lives and painting people is that people are dynamic and constantly moving while still lifes remain stationary. As a result, painting people requires the artist to capture their movement and expression accurately whereas still lives can be copied pixel by pixel from what the artist sees.
# Predicted Grade:  CORRECT
#
# Example 5:
# Question: What did the author learn while working at Interleaf?
# Real Answer: The author learned that low end software tends to eat high end software, that it's better for technology companies to be run by product people than sales people, that it leads to bugs when code is edited by too many people, that cheap office space is no bargain if it's depressing, that planned meetings are inferior to corridor conversations, that big, bureaucratic customers are a dangerous source of money, and that there's not much overlap between conventional office hours and the optimal time for hacking, or conventional offices and the optimal place for it.
# Predicted Answer:  The author learned that technology companies should be run by product people rather than salespeople, that editing code by multiple people can lead to bugs, that cheap office space can be depressing, that planned meetings are less effective than informal conversations, that large, bureaucratic customers can be risky sources of money, and that the optimal time for hacking and office space for programming differ from traditional office hours.
# Predicted Grade:  CORRECT
#
# Example 6:
# Question: What did the author do to survive during the next several years after leaving RISD?
# Real Answer: The author did freelance work for the group that did projects for customers to survive for the next several years after leaving RISD.
# Predicted Answer:  The author worked as a programmer at various companies and eventually started his own business, Viaweb, which became Yahoo Storefronts.
# Predicted Grade:  CORRECT
#
# Example 7:
# Question: What was the author's motivation for wanting to become rich?
# Real Answer: The author wanted to become rich so that he could work on whatever he wanted.
# Predicted Answer:  We don't know.
# Predicted Grade:  INCORRECT
#
# Example 8:
# Question: What is Viaweb and how did it get its name?
# Real Answer: Viaweb is a company that built a web app for creating online stores. It got its name from the fact that the software worked via the web.
# Predicted Answer:  Viaweb was an ecommerce software startup founded by Paul Graham in the mid-1990s. Its goal was to create an easy-to-use and inexpensive solution for online stores, which eventually led to its acquisition by Yahoo in 1998. The name "Viaweb" came from combining the words "via" (meaning "path" or "way") with "web", referring to the World Wide Web.
# Predicted Grade:  CORRECT
#
# Example 9:
# Question: What was the price charged by Viaweb for a small store and a big one?
# Real Answer: $100 a month for a small store and $300 a month for a big one.
# Predicted Answer:  The price charged by Viaweb for a small store was $100 per month and for a big one it was $300 per month.
# Predicted Grade:  CORRECT
#
# Example 10:
# Question: Why did the author hire more people for his startup?
# Real Answer: The author hired more people for his startup partly because the investors wanted him to and partly because that's what startups did during the Internet Bubble.
# Predicted Answer:  The author hired more people for his startup because (a) he wanted to increase the size of his team, (b) his investors wanted him to, or (c) it was a common practice among startups during the Internet Bubble.
# Predicted Grade:  CORRECT
#
# Example 11:
# Question: What was the author's idea for a new company?
# Real Answer: The author's idea was to build a web app for making web apps, where people could edit code on their server through the browser and then host the resulting applications for them.
# Predicted Answer:  The author's idea for a new company was to put art galleries online.
# Predicted Grade:  CORRECT
#
# Example 12:
# Question: What was the author's turning point in figuring out what to work on?
# Real Answer: The author's turning point in figuring out what to work on was when he started publishing essays online.
# Predicted Answer:  The author's turning point in figuring out what to work on was when he started publishing essays online.
# Predicted Grade:  CORRECT
#
# Example 13:
# Question: What is the danger for the ambitious according to the text?
# Real Answer: The desire to impress people is the danger for the ambitious according to the text.
# Predicted Answer:  The danger for the ambitious is the desire to impress people.
# Predicted Grade:  CORRECT
#
# Example 14:
# Question: What is the most distinctive thing about Y Combinator?
# Real Answer: The most distinctive thing about YC is the batch model: to fund a bunch of startups all at once, twice a year, and then to spend three months focusing intensively on trying to help them.
# Predicted Answer:  One of the most distinctive things about Y Combinator is its origins - it was originally called Cambridge Seed and was founded by Paul Graham before becoming known as Y Combinator. Another distinctive aspect of Y Combinator is its focus on early stage startup companies and its use of a "bootcamp" style program to help founders develop their ideas into successful businesses. Additionally, Y Combinator has a unique approach to funding, using a combination of seed funding and mentorship to support entrepreneurs rather than traditional venture capital methods.
# Predicted Grade:  CORRECT
#
# Example 15:
# Question: What was the Summer Founders Program and how many groups were selected for funding?
# Real Answer: The Summer Founders Program was a program for undergrads to apply for funding for their startup ideas. 8 groups were selected for funding out of 225 applications.
# Predicted Answer:  The Summer Founders Program was a program created by Paul Graham to fund startups. He used his own building in Cambridge as the headquarters and held dinners every Tuesday where he brought in experts on startups to speak. From the 225 applicants, around 8 were selected to receive funding.
# Predicted Grade:  CORRECT
#
# Example 16:
# Question: What was the biggest source of stress for the author while working at YC?
# Real Answer: HN (Hacker News)
# Predicted Answer:  It seems likely that the biggest source of stress for the author while working at YC was managing and dealing with Hotwire, which was the company's online auction platform.
# Predicted Grade:  INCORRECT
#
# Example 17:
# Question: What did the author decide to do after leaving YC?
# Real Answer: The author decided to focus on painting.
# Predicted Answer:  The author decided to hand YC over to someone else and focus on his passion - painting.
# Predicted Grade:  CORRECT
#
# Example 18:
# Question: What is the distinctive thing about Lisp?
# Real Answer: The distinctive thing about Lisp is that its core is a language defined by writing an interpreter in itself.
# Predicted Answer:  Lisp is a language defined by writing an interpreter in itself.
# Predicted Grade:  CORRECT
#
# Example 19:
# Question: Why did the author move to England?
# Real Answer: The author moved to England to let their kids experience living in another country and because the author was a British citizen by birth.
# Predicted Answer:  He moved to England with his family in 2016 because he wanted his children to experience living in another country and he was a British citizen by birth.
# Predicted Grade:  CORRECT
#
# Example 20:
# Question: What was the reason behind the change of name from Cambridge Seed to Y Combinator?
# Real Answer: They didn't want a regional name, in case someone copied them in Silicon Valley, so they renamed themselves after one of the coolest tricks in the lambda calculus, the Y combinator.
# Predicted Answer:  The reason behind the change of name from Cambridge Seed to Y Combinator was to avoid having a regional name, in case someone copied them in Silicon Valley.
# Predicted Grade:  CORRECT
#
# Example 21:
# Question: What is the purpose of YC?
# Real Answer: The purpose of YC is to cause startups to be founded that would not otherwise have existed.
# Predicted Answer:  To provide resources and support to early stage startups.
# Predicted Grade:  CORRECT

# %% [markdown]
# ## Valutazione "Manuale"

# %%
## Print Senza Voti
for i, eg in enumerate(dataset):
    print(f"Example {i}:")
    print("QUESTION: " + llm_responses[i]['question'])
    print("REAL ANSWER: " + llm_responses[i]['answer'])
    print("PREDICTED: " + llm_responses[i]['result'])
    print()
# Out:
# Example 0:
# QUESTION: What were the two main things the author worked on before college?
# REAL ANSWER: The two main things the author worked on before college were writing and programming.
# PREDICTED:  The two main things the author worked on before college were writing and programming.
#
# Example 1:
# QUESTION: What made the author want to work on AI?
# REAL ANSWER: The novel 'The Moon is a Harsh Mistress' and a PBS documentary showing Terry Winograd using SHRDLU made the author want to work on AI.
# PREDICTED:  The author wanted to work on AI after reading a novel by Robert Heinlein called The Moon is a Harsh Mistress, which featured an intelligent computer called Mike, and watching a PBS documentary that showed Terry Winograd using SHRDLU.
#
# Example 2:
# QUESTION: What did the author realize while looking at a painting at the Carnegie Institute?
# REAL ANSWER: The author realized that paintings were something that could be made to last and that making them was a way to be independent and make a living.
# PREDICTED:  The author realized that creating art was something that could be done independently and sustainably, and that it was possible for him to make paintings that would last.
#
# Example 3:
# QUESTION: What did the author write their dissertation on?
# REAL ANSWER: The author wrote their dissertation on applications of continuations.
# PREDICTED:  The author wrote their dissertation on On Lisp.
#
# Example 4:
# QUESTION: What is the difference between painting still lives and painting people?
# REAL ANSWER: Painting still lives is different from painting people because the subject, as its name suggests, can't move. People can't sit for more than about 15 minutes at a time, and when they do they don't sit very still. So the traditional m.o. for painting people is to know how to paint a generic person, which you then modify to match the specific person you're painting.
# PREDICTED:  Painting still lives differs from painting people because the former involves painting stationary objects while the latter requires capturing the movement and emotion of a living being.
#
# Example 5:
# QUESTION: What did the author learn while working at Interleaf?
# REAL ANSWER: The author learned that low end software tends to eat high end software, that it's better for technology companies to be run by product people than sales people, that it leads to bugs when code is edited by too many people, that cheap office space is no bargain if it's depressing, that planned meetings are inferior to corridor conversations, that big, bureaucratic customers are a dangerous source of money, and that there's not much overlap between conventional office hours and the optimal time for hacking, or conventional offices and the optimal place for it.
# PREDICTED:  The author learned that it's better for technology companies to be run by product people than sales people; that editing code by too many people can lead to bugs; that cheap office space can be depressing; that planned meetings are inferior to corridor conversations; that big, bureaucratic customers are a dangerous source of money; and that conventional office hours and places aren't ideal for hacking.
#
# Example 6:
# QUESTION: What did the author do to survive during the next several years after leaving RISD?
# REAL ANSWER: The author did freelance work for the group that did projects for customers to survive for the next several years after leaving RISD.
# PREDICTED:  The author painted houses and taught art classes while trying to figure out how to make a living as an artist.
#
# Example 7:
# QUESTION: What was the author's motivation for wanting to become rich?
# REAL ANSWER: The author wanted to become rich so that he could work on whatever he wanted.
# PREDICTED:  The author wanted to become rich so that they could work on whatever they wanted, specifically painting.
#
# Example 8:
# QUESTION: What is Viaweb and how did it get its name?
# REAL ANSWER: Viaweb is a company that built a web app for creating online stores. It got its name from the fact that the software worked via the web.
# PREDICTED:  Viaweb was an early e-commerce platform launched in 1995 by Paul Graham. The name Viaweb comes from the combination of the words "virtual" and "web."
#
# Example 9:
# QUESTION: What was the price charged by Viaweb for a small store and a big one?
# REAL ANSWER: $100 a month for a small store and $300 a month for a big one.
# PREDICTED:  The price charged by Viaweb for a small store was $100 per month, while the price for a big one was $300 per month.
#
# Example 10:
# QUESTION: Why did the author hire more people for his startup?
# REAL ANSWER: The author hired more people for his startup partly because the investors wanted him to and partly because that's what startups did during the Internet Bubble.
# PREDICTED:  The author hired more people for his startup partly because their investors wanted him to, and partly because that's what startups did during the Internet Bubble.
#
# Example 11:
# QUESTION: What was the author's idea for a new company?
# REAL ANSWER: The author's idea was to build a web app for making web apps, where people could edit code on their server through the browser and then host the resulting applications for them.
# PREDICTED:  The author's idea for a new company was to start a company to put art galleries online.
#
# Example 12:
# QUESTION: What was the author's turning point in figuring out what to work on?
# REAL ANSWER: The author's turning point in figuring out what to work on was when he started publishing essays online.
# PREDICTED:  The author's turning point in figuring out what to work on was when they started publishing essays online.
#
# Example 13:
# QUESTION: What is the danger for the ambitious according to the text?
# REAL ANSWER: The desire to impress people is the danger for the ambitious according to the text.
# PREDICTED:  The danger for the ambitious is the desire to impress people, which can lead them astray from their true goals or interests.
#
# Example 14:
# QUESTION: What is the most distinctive thing about Y Combinator?
# REAL ANSWER: The most distinctive thing about YC is the batch model: to fund a bunch of startups all at once, twice a year, and then to spend three months focusing intensively on trying to help them.
# PREDICTED:  The most distinctive thing about Y Combinator is the batch model: to fund a bunch of startups all at once, twice a year, and then to spend three months focusing intensively on trying to help them.
#
# Example 15:
# QUESTION: What was the Summer Founders Program and how many groups were selected for funding?
# REAL ANSWER: The Summer Founders Program was a program for undergrads to apply for funding for their startup ideas. 8 groups were selected for funding out of 225 applications.
# PREDICTED:  The Summer Founders Program was a program created by Paul Graham and his wife Jessica Livingston in 2005. It was designed to provide funding and support for aspiring entrepreneurs during the summer months. Out of the 225 applicants, 8 groups were selected for funding.
#
# Example 16:
# QUESTION: What was the biggest source of stress for the author while working at YC?
# REAL ANSWER: HN (Hacker News)
# PREDICTED:  According to the passage provided, the biggest source of stress for the author while working at YC was handling issues related to Hacker News (HN).
#
# Example 17:
# QUESTION: What did the author decide to do after leaving YC?
# REAL ANSWER: The author decided to focus on painting.
# PREDICTED:  The author decided to paint.
#
# Example 18:
# QUESTION: What is the distinctive thing about Lisp?
# REAL ANSWER: The distinctive thing about Lisp is that its core is a language defined by writing an interpreter in itself.
# PREDICTED:  The distinctive thing about Lisp is that its core is a language defined by writing an interpreter in itself.
#
# Example 19:
# QUESTION: Why did the author move to England?
# REAL ANSWER: The author moved to England to let their kids experience living in another country and because the author was a British citizen by birth.
# PREDICTED:  The author moved to England because they wanted their children to experience living in another country, and since the author was a British citizen by birth, England seemed like the obvious choice.
#
# Example 20:
# QUESTION: What was the reason behind the change of name from Cambridge Seed to Y Combinator?
# REAL ANSWER: They didn't want a regional name, in case someone copied them in Silicon Valley, so they renamed themselves after one of the coolest tricks in the lambda calculus, the Y combinator.
# PREDICTED:  Y Combinator was not the original name. At first we were called Cambridge Seed. But we didn't want a regional name, in case someone copied us in Silicon Valley, so we renamed ourselves after one of the coolest tricks in the lambda calculus, the Y combinator.
#
# Example 21:
# QUESTION: What is the purpose of YC?
# REAL ANSWER: The purpose of YC is to cause startups to be founded that would not otherwise have existed.
# PREDICTED:  The purpose of YC is to provide a support system for entrepreneurs to grow their businesses through mentorship, networking opportunities, and financial resources.
